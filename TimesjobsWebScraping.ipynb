# %%
from bs4 import BeautifulSoup
import requests

# %%
url= 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation='
html_text= requests.get(url).text
soup = BeautifulSoup(html_text, 'lxml')

# %%
#find the first company in the list offering job along with required skills and published date
from bs4 import BeautifulSoup
import requests
url= 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation='
html_text= requests.get(url).text
soup = BeautifulSoup(html_text, 'lxml')
job1= soup.find('li', class_='clearfix job-bx wht-shd-bx')
company1=job1.find('h3',class_='joblist-comp-name').text.replace(' ','')
skills1=job1.find('span',class_='srp-skills').text
published_date1= job1.find('span',class_= 'sim-posted').text

print(f"Company Name: {company1.strip()}")
print(f"Required Skills: {skills1.strip()}")
print(f"Job publish date: {published_date1}")
# Out:
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: python development   ,   object oriented programming   ,   test driven development   ,   database connectors   ,   linux environment   ,  git  ,  api
# Job publish date:
# Posted few days ago

# %%
#find all the companies in the list offering job along with required skills and published date
from bs4 import BeautifulSoup
import requests
url= 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation='
html_text= requests.get(url).text
soup = BeautifulSoup(html_text, 'lxml')
jobs= soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
for job in jobs:
    company=job.find('h3',class_='joblist-comp-name').get_text(strip=True).replace(' ','')
    skills=job.find('span',class_='srp-skills').get_text(strip=True)
    published_date= job.find('span',class_= 'sim-posted').get_text(strip=True)
    
    print(f"Company Name: {company.strip()}")
    print(f"Required Skills: {skills.strip()}")
    print(f"Job publish date: {published_date}")
    print('')
# Out:
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: pythondevelopment   ,   object oriented programming   ,   test driven development   ,   database connectors   ,   linux environment   ,  git  ,  api
# Job publish date: Posted few days ago
#
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: pythonprogramming   ,   data analysis   ,   data visualization   ,   database management   ,   requirements gathering   ,  data mining  ,  sql
# Job publish date: Posted a month ago
#
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: data analysis  ,   communication  ,   problem solving  ,   microsoft office  ,   visualization tools    ,  data analytics  ,  data analyst  ,  sql  ,  tableau  ,  written communication
# Job publish date: Posted few days ago
#
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: python,   javascript   ,   sql   ,   restful web services   ,   system design   ,  css  ,  git  ,  html
# ...

# %%
#find all the companies in the list offering job along with required skills and published date whivh have been posted a few days ago only
from bs4 import BeautifulSoup
import requests
url= 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation='
html_text= requests.get(url).text
soup = BeautifulSoup(html_text, 'lxml')
jobs= soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
for job in jobs:
    published_date= job.find('span',class_= 'sim-posted').get_text(strip=True)
    if 'few' in published_date:
        company=job.find('h3',class_='joblist-comp-name').get_text(strip=True).replace(' ','')
        skills=job.find('span',class_='srp-skills').get_text(strip=True)
        
        print(f"Company Name: {company.strip()}")
        print(f"Required Skills: {skills.strip()}")
        print(f"Job publish date: {published_date}")
        print('')
# Out:
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: pythondevelopment   ,   object oriented programming   ,   test driven development   ,   database connectors   ,   linux environment   ,  git  ,  api
# Job publish date: Posted few days ago
#
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: data analysis  ,   communication  ,   problem solving  ,   microsoft office  ,   visualization tools    ,  data analytics  ,  data analyst  ,  sql  ,  tableau  ,  written communication
# Job publish date: Posted few days ago
#
# Company Name: CONNECTING2WORK
# Required Skills: rest  ,python,  django  ,  mongodb
# Job publish date: Posted few days ago
#
# Company Name: eastindiasecuritiesltd.
# Required Skills: python,  hadoop  ,  machine learning
# Job publish date: Posted few days ago
#
# Company Name: LAKSHHUMANRESOURCE
# Required Skills: rest  ,python,  django  ,  git
# Job publish date: Posted few days ago
#
# Company Name: DREAMAJAXTECHNOLOGIES
# ...

# %%
#find all the companies in the list offering job along with their job description
from bs4 import BeautifulSoup
import requests
url= 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation='
html_text= requests.get(url).text
soup = BeautifulSoup(html_text, 'lxml')
jobs= soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
for job in jobs:
    company=job.find('h3',class_='joblist-comp-name').get_text(strip=True).replace(' ','')
    url= job.header.h2.a['href']
    more_info_html= requests.get(url).text
    soup2 = BeautifulSoup(more_info_html, 'lxml')
    job_desc=soup2.find('code',class_='language-markdown')
    if job_desc:
        print(f"Company Name: {company.strip()}")
        print(f"Job Description: {job_desc.text}")
    else:
        print("Job description not found or the HTML structure has changed.")
# Out:
# Company Name: virtusaconsultingservicespvt.ltd.
# Job Description: ##  Python - CREQ193122
#
# ### Description
# Extensive practical experience working with most if not all the technologies listed belowPython development with hands-on experience with Object Oriented Programming including Design PatternsStrong Knowledge in Database connectors, Stream/Batch processing, API DevelopmentKnowledge on Test Driven DevelopmentFamiliarity with Linux environment including scripting skillsSDLC/Dev Ops - Git/BitBucket, CI/CD pipeline frameworks such as Jenkins, SonarQube, JIRA, Any secure coding toolkits.Exposure to Mathematics/computer science is preferred. Candidate should have exposure to mathematical modelling/finance insights. No ML/AI/Web exposure is required.
#
# ### Primary Location
# Pune, Maharashtra, India
#
# ### Job Type
# Experienced
#
# ### Primary Skills
# Python
#
# ### Years of Experience
# 8
#
# ### Qualification
# ...

# %%
#find all the companies in the list offering job filtering by the skill entered by user
from bs4 import BeautifulSoup
import requests
url= 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation='
html_text= requests.get(url).text
soup = BeautifulSoup(html_text, 'lxml')
filter=input("Enter skill: ").strip()
print(f"Filtering by {filter}")
jobs= soup.find_all('li', class_='clearfix job-bx wht-shd-bx')
for job in jobs:
    company=job.find('h3',class_='joblist-comp-name').get_text(strip=True).replace(' ','')
    skills=job.find('span',class_='srp-skills').get_text(strip=True)
    if filter.lower() in skills.lower():        
        print(f"Company Name: {company.strip()}")
        print(f"Required Skills: {skills}")
        print('')
# Out:
# Enter skill:  DATA ANALYSIS
# Filtering by DATA ANALYSIS
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: pythonprogramming   ,   data analysis   ,   data visualization   ,   database management   ,   requirements gathering   ,  data mining  ,  sql
#
# Company Name: virtusaconsultingservicespvt.ltd.
# Required Skills: data analysis  ,   communication  ,   problem solving  ,   microsoft office  ,   visualization tools    ,  data analytics  ,  data analyst  ,  sql  ,  tableau  ,  written communication
